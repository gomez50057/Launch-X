# %% [markdown]
# # Manejo de errores
#
# Leer y usar la salida de errores de las excepciones Controlar correctamente las excepciones Generar excepciones con mensajes de error útiles Usar excepciones para controlar el flujo de un programa
#
# # Tracebacks

# %%
from IPython.display import Image
Image(filename="Modulo10Katas\img\Katas10.png" )

# %%
from IPython.display import Image
Image(filename="Modulo10Katas\img\Katas10-.png" )

# %% [markdown]
# # Try y Except de los bloques

# %%
from IPython.display import Image
Image(filename="Modulo10Katas\img\Katas10-config.png" )

# %%
from IPython.display import Image
Image(filename="Modulo10Katas\img\Katas10-config2.png" )

# %%
from IPython.display import Image
Image(filename="Modulo10Katas\img\Katas10-config3.png" )

# %%
from IPython.display import Image
Image(filename="Modulo10Katas\img\Katas10-config4.png" )

# %%
from IPython.display import Image
Image(filename="Modulo10Katas\img\Katas10-config5.png" )

# %% [markdown]
# # Generación de excepciones
#
# La generación de excepciones también puede ayudar en la toma de decisiones para otro código. Como hemos visto antes, en función del error, el código puede tomar decisiones inteligentes para resolver, solucionar o ignorar un problema.
#
# Los astronautas limitan su uso de agua a unos 11 litros al día. Vamos a crear una función que, con base al número de astronautas, pueda calcular la cantidad de agua quedará después de un día o más:

# %%
def water_left(astronauts, water_left, days_left):
    daily_usage = astronauts * 11
    total_usage = daily_usage * days_left
    total_water_left = water_left - total_usage
    return f"Total water left after {days_left} days is: {total_water_left} liters"
water_left(5, 100, 2)
# Out:
# 'Total water left after 2 days is: -10 liters'

# %% [markdown]
# El sistema de navegación podría alertar a los astronautas que no habrá suficiente agua para todos en dos días, podrías generar una excepción en la función water_left() para alertar de la condición de error:

# %%
from IPython.display import Image
Image(filename="Modulo10Katas\img\Katas10-astro.png" )

# %%
from IPython.display import Image
Image(filename="Modulo10Katas\img\Katas10-astro2.png" )

# %%
from IPython.display import Image
Image(filename="Modulo10Katas\img\Katas10-astro3.png" )

# %%
from IPython.display import Image
Image(filename="Modulo10Katas\img\Katas10-astro4.png" )
